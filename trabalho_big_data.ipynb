# %% [markdown]
# <a href="https://colab.research.google.com/github/AdilsonFilho23/Trabalho-Big-data/blob/main/trabalho_big_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install ydata_profiling
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.6/390.6 kB 25.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 24.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 686.1/686.1 kB 40.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 9.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 90.4 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=fa0401faf1dd636cb3ecaf45e6b3f3ccec3e42e0f4433f715cf58555bd486b12
#   Stored in directory: /root/.cache/pip/wheels/dd/91/29/a79cecb328d01739e64017b6fb9a1ab9d8cb1853098ec5966d
# Successfully built htmlmin
# ...

# %%
import pandas as pd
from ydata_profiling import ProfileReport
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
treino = pd.read_csv('train.csv')
treino.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
profile = ProfileReport(treino, title="titanic_treino")

# %%
# Criando o relatório
profile.to_file("titanic_treino.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# Verificando as informações da base
treino.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# Verificando o tipo dos dados
treino.dtypes.value_counts()
# Out:
# int64      5
# object     5
# float64    2
# Name: count, dtype: int64

# %%
# Verirficando os valores nulos
treino.isnull().sum().sort_values(ascending=False).head(5)
# Out:
# Cabin          687
# Age            177
# Embarked         2
# PassengerId      0
# Survived         0
# dtype: int64

# %%
# Visualizando a base de teste
teste = pd.read_csv('test.csv')
teste.head(3)
# Out:
#    PassengerId  Pclass                              Name     Sex   Age  SibSp  \
# 0          892       3                  Kelly, Mr. James    male  34.5      0
# 1          893       3  Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2          894       2         Myles, Mr. Thomas Francis    male  62.0      0
#
#    Parch  Ticket    Fare Cabin Embarked
# 0      0  330911  7.8292   NaN        Q
# 1      0  363272  7.0000   NaN        S
# 2      0  240276  9.6875   NaN        Q

# %%
# Verificando as informações da base
teste.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
# Analisando os valores nulos
teste.isnull().sum().sort_values(ascending=False).head(5)
# Out:
# Cabin          327
# Age             86
# Fare             1
# PassengerId      0
# Pclass           0
# dtype: int64

# %%
# Verificando novamente valores vazios para a base de treino
treino.isnull().sum().sort_values(ascending=False).head(5)
# Out:
# Cabin          687
# Age            177
# Embarked         2
# PassengerId      0
# Survived         0
# dtype: int64

# %%
# Retornando o shape da base
treino.shape
# Out:
# (891, 12)

# %%
treino.head(4)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
# Verificando a cardinalidade dos dados
treino.nunique().sort_values(ascending=False)
# Out:
# PassengerId    891
# Name           891
# Ticket         681
# Fare           248
# Cabin          147
# Age             88
# SibSp            7
# Parch            7
# Pclass           3
# Embarked         3
# Survived         2
# Sex              2
# dtype: int64

# %%
# Eliminando para a base de treino
treino = treino.drop(['Name','Ticket','Cabin'],axis=1)

# %%
# Também eliminando para a base de teste
teste = teste.drop(['Name','Ticket','Cabin'],axis=1)

# %%
# Verificando a média das idades para a base de treino
treino.Age.mean()
# Out:
# 29.69911764705882

# %%
# Substituir as colunas com idade vazia por uma média
treino.loc[treino.Age.isnull(),'Age'] = treino.Age.mean()

# %%
# Fazer o mesmo para a base de teste
teste.loc[teste.Age.isnull(),'Age'] = teste.Age.mean()

# %%
# Verificando os valores na coluna Embarked
treino.Embarked.value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
# Selecionando a moda dessa coluna
treino.Embarked.mode()[0]
# Out:
# 'S'

# %%
# Substituindo os valores vazios
treino.loc[treino.Embarked.isnull(),'Embarked'] = treino.Embarked.mode()[0]

# %%
# Verificando a média da coluna Fare para a base de teste
teste.loc[teste.Fare.isnull(),'Fare'] = teste.Fare.mean()

# %%
# Para a base de treino
treino.isnull().sum().sort_values(ascending=False).head(5)
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# dtype: int64

# %%
# Para a base de teste
teste.isnull().sum().sort_values(ascending=False).head(5)
# Out:
# PassengerId    0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# dtype: int64

# %%
# Verificando as colunas de texto na base de treino
col_treino_nr = treino.columns[treino.dtypes != 'object']
col_treino_nr
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
# Selecionar apenas os valores numéricos da base de treino
treino_nr = treino.loc[:,col_treino_nr]

# %%
# Fazer o mesmo para a base de teste
col_teste_nr = teste.columns[teste.dtypes != 'object']
col_teste_nr
# Out:
# Index(['PassengerId', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
# Selecionar apenas os valores numéricos da base de teste
teste_nr = teste.loc[:,col_teste_nr]

# %%
# Separando a base de treino em X e y
X = treino_nr.drop(['PassengerId','Survived'],axis=1)
y = treino.Survived

# %%
# Separando em treino e validação
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
# Criando o classificador da árvore de classificação
clf_ac = tree.DecisionTreeClassifier(random_state=42)

# %%
# Fit com os dados
clf_ac = clf_ac.fit(X_train,y_train)

# %%
# Previsão
y_pred_ac = clf_ac.predict(X_val)

# %%
# Criando o classificador para o K-Nearest Neighbors
clf_knn = KNeighborsClassifier(n_neighbors=3)

# %%
# Fit com os dados
clf_knn = clf_knn.fit(X_train,y_train)

# %%
# Previsão
y_pred_knn = clf_knn.predict(X_val)

# %%
# Criando o classificador da regressão logística
clf_rl = LogisticRegression(random_state=42)

# %%
# Fit com os dados
clf_rl = clf_rl.fit(X_train,y_train)

# %%
# Previsão
y_pred_rl = clf_rl.predict(X_val)

# %%
# Score para a árvore
accuracy_score(y_val, y_pred_ac)
# Out:
# 0.6169491525423729

# %%
# Score para o knn
accuracy_score(y_val, y_pred_knn)
# Out:
# 0.6610169491525424

# %%
# Score para a regressão logística
accuracy_score(y_val, y_pred_rl)
# Out:
# 0.7254237288135593

# %%
# Matriz de confusão para a árvore
confusion_matrix(y_val, y_pred_ac)
# Out:
# array([[125,  50],
#        [ 63,  57]])

# %%
# Matriz de confusão para o knn
confusion_matrix(y_val, y_pred_knn)
# Out:
# array([[133,  42],
#        [ 58,  62]])

# %%
# Visualizando o X_train
X_train.head(3)
# Out:
#      Pclass        Age  SibSp  Parch     Fare
# 6         1  54.000000      0      0  51.8625
# 718       3  29.699118      0      0  15.5000
# 685       2  25.000000      1      2  41.5792

# %%
# Visualizando a base de teste (apenas com valores numéricos)
teste_nr.head(3)
# Out:
#    PassengerId  Pclass   Age  SibSp  Parch    Fare
# 0          892       3  34.5      0      0  7.8292
# 1          893       3  47.0      1      0  7.0000
# 2          894       2  62.0      0      0  9.6875

# %%
# Éliminar a coluna de id para a base de teste ser igual a base de treino
X_teste = teste_nr.drop("PassengerId",axis=1)

# %%
# Regressão logística na base de teste
y_pred = clf_rl.predict(X_teste)

# %%
# Criando uma nova coluna com a previsão na base de teste
teste['Survived'] = y_pred

# %%
# Selecionando apenas a coluna de Id e Survived para fazer o envio
base_envio = teste[['PassengerId','Survived']]

# %%
# Exportar para um csv
base_envio.to_csv('resultados2.csv',index=False)
